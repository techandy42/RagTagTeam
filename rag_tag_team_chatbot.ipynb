# %% [markdown]
# <a href="https://colab.research.google.com/github/techandy42/RagTagTeam/blob/main/rag_tag_team_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
COHERE_API_KEY = "LFwtrOMC4TCNjslyIJG6f7vGAENVzC7mwT8NXo8r"

# %%
profile1 = {
    "software_engineer": "Karan Gupta",
    "profile_url": "https://www.linkedin.com/in/karangupta/",
    "background": "Raised in Toronto, Canada, Karan Gupta is a seasoned software engineer with over a decade of experience in the industry. With a strong background in computer science and a passion for solving complex problems, he has made significant contributions to various projects throughout his career. Currently, he is working at Amazon as a Senior Software Engineer, leading a team of talented engineers in developing innovative solutions for the company.",
    "experience": [
      {
        "position": "Senior Software Engineer at Amazon",
        "duration": "Oct 2020 - Present",
        "location": "Seattle, WA, USA",
        "responsibilities": [
          "Lead a team of engineers in designing and implementing software solutions for Amazon's e-commerce platform",
          "Played a key role in developing new features and improving existing ones, focusing on enhancing the user experience and optimizing performance",
          "Collaborate with cross-functional teams, including product managers, designers, and quality assurance engineers, to ensure timely delivery of projects"
        ]
      },
      {
        "position": "Software Engineer at Google",
        "duration": "Oct 2015 - Sep 2020",
        "location": "Mountain View, CA, USA",
        "responsibilities": [
          "Collaborated with a team of engineers on Google Search to improve the relevance and speed of search results",
          "Assisted in the development of machine learning algorithms to enhance the accuracy of search predictions and recommendations",
          "Partnered with UX researchers to conduct user studies and gather feedback on search functionalities"
        ]
      },
      {
        "position": "Software Engineer at Microsoft",
        "duration": "Jul 2013 - Oct 2015",
        "location": "Redmond, WA, USA",
        "responsibilities": [
          "Contributed to the development of the Windows operating system, with a focus on improving the compatibility of applications across different devices",
          "Collaborated with a team of engineers in designing and implementing solutions for improving the reliability of Windows Updates"
        ]
      }
    ],
    "education": [
      {
        "degree": "Bachelor of Science in Computer Science",
        "university": "University of Toronto",
        "location": "Toronto, Canada",
        "graduation_year": "2011"
      }
    ],
    "skills": [
      "Full-Stack Engineering",
      "Cloud Computing (AWS, GCP)",
      "Microservices Architecture",
      "Database Management",
      "Software Design Patterns",
      "Machine Learning",
      "Python",
      "C++",
      "JavaScript",
      "React",
      "Angular",
      "SQL"
    ]
  }

# %%
profile2 = {
    "software_engineer": "Jessica Zhang",
    "profile_url": "https://www.linkedin.com/in/jessica-zhang-a00b6651/",
    "background": "Jessica Zhang is a self-driven and ambitious software engineer with a strong passion for leveraging technology to solve complex business problems. Throughout her career, she has gained experience in various programming languages and frameworks, demonstrating her versatility and adaptability in the field. She is currently a Software Engineer at LinkedIn, where she collaborates with a talented team to develop innovative solutions for the world's largest professional network.",
    "experience": [
      {
        "position": "Software Engineer at LinkedIn",
        "duration": "Oct 2022 - Present",
        "location": "San Francisco, CA, USA",
        "responsibilities": [
          "Work with a team of engineers to design and implement new features for LinkedIn's mobile application",
          "Contribute to the development of the company's machine learning-powered recommendation engine, leveraging Python and TensorFlow to improve user experience",
          "Collaborate with data scientists and product managers to translate business requirements into technical specifications"
        ]
      },
      {
        "position": "Intern Software Engineer at Apple",
        "duration": "Jun 2021 - Sep 2021",
        "location": "Cupertino, CA, USA",
        "responsibilities": [
          "Collaborated with a team of engineers on the Apple News platform to improve article recommendations for users",
          "Assisted in developing new features for the Apple News iOS application, leveraging Swift and React Native",
          "Conducted code reviews and provided feedback to fellow interns on their projects"
        ]
      },
      {
        "position": "Software Engineer at Goldman Sachs",
        "duration": "Sep 2019 - May 2021",
        "location": "New York, NY, USA",
        "responsibilities": [
          "Developed an internal tool for managing and analyzing trade data using Java, Spring Boot, and React",
          "Collaborated with stakeholders to identify areas where process improvement and automation could be implemented using machine learning algorithms",
          "Conducted code reviews and served as a mentor for junior engineers"
        ]
      }
    ],
    "education": [
      {
        "degree": "Bachelor of Engineering in Computer Science",
        "university": "Peking University",
        "location": "Beijing, China",
        "graduation_year": "2019"
      }
    ],
    "skills": [
      "Full-Stack Engineering",
      "Machine Learning",
      "Recommender Systems",
      "Java",
      "Python",
      "Swift",
      "React Native",
      "React",
      "Spring Boot",
      "TensorFlow",
      "SQL"
    ]
  }

# %%
profile3 = {
    "software_engineer": "Sophia Yang",
    "profile_url": "https://www.linkedin.com/in/sophia-yang-0825/",
    "background": "Sophia Yang is a passionate and innovative software engineer with experience in full-stack web development and a strong background in computer science. Throughout her career, she has consistently demonstrated a keen eye for detail, a problem-solving mindset, and a dedication to delivering high-quality software solutions. Sophia is particularly skilled in Agile methodologies and collaborative work environments.",
    "experience": [
      {
        "position": "Software Engineer at Google",
        "duration": "Sep 2021 - Present",
        "location": "Mountain View, CA, USA",
        "responsibilities": [
          "Worked on the Google Search team to improve search result relevancy and user experience",
          "Utilized Python, Java, and TensorFlow to develop and optimize machine learning models for search ranking",
          "Collaborated with designers and user experience researchers to gather feedback and test new search features"
        ]
      },
      {
        "position": "Software Engineer at Microsoft",
        "duration": "Jul 2019 - Sep 2021",
        "location": "Redmond, WA, USA",
        "responsibilities": [
          "Contributed to the development of Azure, Microsoft's cloud computing platform",
          "Assisted in building tools and services for managing and deploying cloud-based applications",
          "Collaborated with a cross-functional team of engineers, designers, and product managers to enhance user experience"
        ]
      },
      {
        "position": "Intern Software Engineer at Apple",
        "duration": "Dec 2017 - Aug 2018",
        "location": "Cupertino, CA, USA",
        "responsibilities": [
          "Collaborated with a team of engineers to develop a new feature for Apple News",
          "Utilized Swift and Objective-C to implement the feature and improve user experience",
          "Conducted code reviews and provided feedback to fellow interns on their projects"
        ]
      }
    ],
    "education": [
      {
        "degree": "Bachelor of Engineering in Computer Science and Engineering",
        "university": "Peking University",
        "location": "Beijing, China",
        "graduation_year": "2019"
      }
    ],
    "skills": [
      "Full-Stack Engineering",
      "Cloud Computing (Azure)",
      "Web Development (React, Angular, Django)",
      "Machine Learning",
      "Python",
      "Java",
      "Swift",
      "Objective-C",
      "TensorFlow",
      "Agile Methodologies",
      "SQL"
    ]
  }

# %%
profile4 = {
    "software_engineer": "Richard Yu",
    "profile_url": "https://www.linkedin.com/in/richard-yu-DataScience/",
    "background": "Richard Yu is a skilled software engineer and data scientist with a passion for leveraging technology to extract insights and drive innovation. Throughout his career, he has worked in various industries, including finance, e-commerce, and healthcare, developing robust software solutions and leveraging data to inform business decisions. He is currently a Senior Software Engineer at Goldman Sachs, where he leads a team in developing cutting-edge trading systems.",
    "experience": [
      {
        "position": "Senior Software Engineer at Goldman Sachs",
        "duration": "Jun 2020 - Present",
        "location": "New York, NY, USA",
        "responsibilities": [
          "Lead a team of engineers in developing high-frequency trading systems and algorithms, focusing on improving execution speed and reducing latency",
          "Collaborate with quantitative analysts and traders to define requirements and test trading strategies",
          "Engage with stakeholders to gather feedback and prioritize engineering initiatives"
        ]
      },
      {
        "position": "Software Engineer at Citigroup",
        "duration": "Jul 2018 - Jun 2020",
        "location": "New York, NY, USA",
        "responsibilities": [
          "Developed a new web-based trading platform for the bank's investment banking division, improving usability and accessibility for clients",
          "Collaborated with stakeholders to gather requirements and prioritize development tasks",
          "Conducted code reviews and provided guidance to junior engineers"
        ]
      },
      {
        "position": "Software Engineer at Alibaba",
        "duration": "Jul 2016 - Jul 2018",
        "location": "Hangzhou, China",
        "responsibilities": [
          "Collaborated with a team of engineers to develop an e-commerce platform for small and medium-sized enterprises",
          "Played a key role in designing and implementing a new recommendation system for the platform, using machine learning algorithms to improve user experience",
          "Conducted A/B testing to evaluate the impact of new features on user engagement"
        ]
      }
    ],
    "education": [
      {
        "degree": "Bachelor of Engineering in Computer Science",
        "university": "Tsinghua University",
        "location": "Beijing, China",
        "graduation_year": "2016"
      }
    ],
    "skills": [
      "Full-Stack Engineering",
      "Machine Learning",
      "Web Development (React, Django)",
      "Cloud Computing (AWS)",
      "Data Science",
      "Python",
      "C++",
      "Java",
      "React Native",
      "SQL",
      "Quantitative Finance",
      "Algorithmic Trading"
    ]
  }

# %%
profile5 = {
    "software_engineer": "Alex Liu",
    "profile_url": "https://www.linkedin.com/in/alexliu/",
    "background": "Alex Liu is a passionate and ambitious software engineer with a strong background in computer science and a keen interest in exploring new technologies. Throughout his career, he has gained experience in various programming languages, frameworks, and industries, demonstrating his versatility and adaptability. Alex is particularly skilled in agile methodologies, software design patterns, and collaboration.",
    "experience": [
      {
        "position": "Software Engineer at Google",
        "duration": "Oct 2022 - Present",
        "location": "Mountain View, CA, USA",
        "responsibilities": [
          "Collaborated with a team of engineers to design and implement new features for Google Maps, focusing on improving the user experience and accuracy of location data",
          "Utilized Python, JavaScript, and Go programming languages to develop and maintain the mapping platform",
          "Conducted code reviews and provided feedback to team members on their contributions"
        ]
      },
      {
        "position": "Software Engineer at Microsoft",
        "duration": "Jul 2021 - Oct 2022",
        "location": "Redmond, WA, USA",
        "responsibilities": [
          "Contributed to the development of Microsoft Teams, focusing on improving the performance and scalability of the communication platform",
          "Collaborated with a cross-functional team of engineers, designers, and product managers to gather requirements and plan development activities",
          "Conducted root cause analysis and resolved critical issues impacting the user experience"
        ]
      },
      {
        "position": "Software Engineer at Apple",
        "duration": "Jan 2020 - Jul 2021",
        "location": "Cupertino, CA, USA",
        "responsibilities": [
          "Collaborated with a team of engineers to design and implement a new feature for the Apple Wallet app, allowing users to store and use their credit cards for contactless payments",
          "Utilized Swift and JavaScript to develop and maintain the wallet feature, ensuring security and privacy of user financial data",
          "Conducted testing and debugging to ensure the feature works seamlessly across different devices and platforms"
        ]
      }
    ],
    "education": [
      {
        "degree": "Bachelor of Science in Computer Science",
        "university": "University of Waterloo",
        "location": "Waterloo, Canada",
        "graduation_year": "2019"
      }
    ],
    "skills": [
      "Full-Stack Engineering",
      "Mobile Development (iOS)",
      "Web Development (React, Angular)",
      "Cloud Computing (AWS)",
      "Agile Methodologies",
      "Software Design Patterns",
      "Python",
      "Swift",
      "JavaScript",
      "Go",
      "React Native",
      "Angular",
      "SQL"
    ]
  }

# %%
profile6 = {
    "software_engineer": "Sophia Wang",
    "profile_url": "https://www.linkedin.com/in/sophia-wang-0825/",
    "background": "Sophia Wang is a passionate software engineer with experience in both front-end and back-end development. She is skilled in various programming languages, frameworks, and design patterns, and has a strong understanding of software architecture and development processes. Sophia is particularly interested in developing user-friendly and scalable web applications.",
    "experience": [
      {
        "position": "Software Engineer at LinkedIn",
        "duration": "Jul 2021 - Present",
        "location": "San Francisco, CA, USA",
        "responsibilities": [
          "Worked on the LinkedIn Jobs team to improve the user experience of applying for jobs on the platform",
          "Utilized JavaScript, Python, and GraphQL to develop and maintain the job application process",
          "Collaborated with designers and product managers to gather feedback and test new features"
        ]
      },
      {
        "position": "Software Engineer at Google",
        "duration": "Oct 2020 - Jul 2021",
        "location": "Mountain View, CA, USA",
        "responsibilities": [
          "Collaborated with a team of engineers to develop a new feature for Google Search, allowing users to filter search results by date",
          "Utilized JavaScript, Python, and Go to develop and maintain the new filtering functionality",
          "Conducted A/B testing to evaluate the impact of the new feature on user engagement"
        ]
      },
      {
        "position": "Software Engineer at Microsoft",
        "duration": "Aug 2019 - Oct 2020",
        "location": "Redmond, WA, USA",
        "responsibilities": [
          "Contributed to the development of Microsoft Teams, focusing on improving the quality and reliability of the communication platform",
          "Collaborated with a team of engineers to identify and resolve critical bugs impacting the user experience",
          "Utilized C#, .NET Core, and Azure to develop and maintain the Microsoft Teams backend"
        ]
      }
    ],
    "education": [
      {
        "degree": "Bachelor of Engineering in Computer Science and Engineering",
        "university": "Peking University",
        "location": "Beijing, China",
        "graduation_year": "2019"
      }
    ],
    "skills": [
      "Full-Stack Engineering",
      "Web Development (React, Angular, Django)",
      "Machine Learning",
      "Cloud Computing (AWS)",
      "Python",
      "C#",
      ".NET Core",
      "React Native",
      "Angular",
      "SQL",
      "Golang",
      "GraphQL"
    ]
  }

# %%
profiles = []

for i in range(50):
  profiles.append(profile1)
  profiles.append(profile2)
  profiles.append(profile3)
  profiles.append(profile4)
  profiles.append(profile5)
  profiles.append(profile6)

# %%
# !pip install cohere hnswlib unstructured -q

# %%
import cohere
import os
import hnswlib
import json
import uuid
from typing import List, Dict
from unstructured.partition.html import partition_html
from unstructured.chunking.title import chunk_by_title
import json

co = cohere.Client(COHERE_API_KEY)

# %%
def preprocess(dict_data):
    # Take in a dict_data and convert it to a string with an associated user id
    experiences = ""
    for experience in dict_data["experience"]:
        responsibilities = ""
        for responsibility in experience["responsibilities"]:
          responsibilities = responsibilities +  responsibility  + "\n"
        experiences += (
            f"Position: {experience['position']}\n"
            f"Duration: {experience['duration']}\n"
            f"Location: {experience['location']}\n"
            f"Responsibilities: {responsibilities}\n"
        )
    skills = ""
    for skill in dict_data["skills"]:
        skills += f"{skill}\n"

    educations = ""
    for education in dict_data["education"]:
        educations += (
            f"Degree: {education['degree']}\n"
            f"University: {education['university']}\n"
            f"Location: {education['location']}\n"
            f"Graduation Year: {education['graduation_year']}\n"
        )

    linkedinstring = (
        f"Name: {dict_data['software_engineer']}\n"
        f"Background: {dict_data['background']}\n"
        f"Experiences: {experiences}\n"
        f"Education: {educations}\n"
        f"Skills: {skills}\n"
    )
    return linkedinstring

# %%
class Documents:
  def __init__(self, sources: List[Dict[str, str]]):
    self.sources = sources
    self.docs = []
    self.docs_embs = []
    self.retrieve_top_k = 10
    self.rerank_top_k = 3
    self.load()
    self.embed()
    self.index()

  def load(self) -> None:
    for index, source in enumerate(self.sources):
      self.docs.append({'text': preprocess(source), 'id': index})

  def embed(self) -> None:
    """
    Embeds the documents using the Cohere API.
    """
    print("Embedding documents...")

    batch_size = 90
    self.docs_len = len(self.docs)

    for i in range(0, self.docs_len, batch_size):
      batch = self.docs[i : min(i + batch_size, self.docs_len)]
      texts = [item['text'] for item in batch]
      docs_embs_batch = co.embed(
        texts=texts,
        model="embed-english-v3.0",
        input_type="search_document"
	 		).embeddings
      self.docs_embs.extend(docs_embs_batch)

  def index(self) -> None:
    """
    Indexes the documents for efficient retrieval.
    """
    print("Indexing documents...")

    self.index = hnswlib.Index(space="ip", dim=1024)
    self.index.init_index(max_elements=self.docs_len, ef_construction=512, M=64)
    self.index.add_items(self.docs_embs, list(range(len(self.docs_embs))))

    print(f"Indexing complete with {self.index.get_current_count()} documents.")

  def retrieve(self, query: str) -> List[Dict[str, str]]:
    """
    Retrieves documents based on the given query.

    Parameters:
    query (str): The query to retrieve documents for.

    Returns:
    List[Dict[str, str]]: A list of dictionaries representing the retrieved  documents, with 'title', 'snippet', and 'url' keys.
    """
    docs_retrieved = []
    query_emb = co.embed(
      texts=[query],
      model="embed-english-v3.0",
      input_type="search_query"
    ).embeddings

    doc_ids = self.index.knn_query(query_emb, k=self.retrieve_top_k)[0][0]

    docs_to_rerank = []
    for doc_id in doc_ids:
        docs_to_rerank.append(self.docs[doc_id])

    rerank_results = co.rerank(
        query=query,
        documents=docs_to_rerank,
        top_n=self.rerank_top_k,
        model="rerank-english-v2.0",
    )

    doc_ids_reranked = []
    for result in rerank_results:
        doc_ids_reranked.append(doc_ids[result.index])

    for doc_id in doc_ids_reranked:
        docs_retrieved.append(
            {
                "text": self.docs[doc_id]['text'],
                "id": self.docs[doc_id]['id']
            }
        )

    sources_retrieved = []

    for docs_retrieved_item in docs_retrieved:
      sources_retrieved.append(self.sources[docs_retrieved_item['id']])

    return sources_retrieved, docs_retrieved

# %%
documents = Documents(profiles)
# Out:
# Embedding documents...
# Indexing documents...
# Indexing complete with 300 documents.

# %%
sources, docs = documents.retrieve("Please provide a matching score out of 10 based on skillset and personality. Provide a graph of skillset and personality.")

# %%
# sources, docs

# %%
class SearchEngine:
  def __init__(self, docs: Documents):
    self.documents = documents
    self.conversation_id = str(uuid.uuid4())

  def generate_response(self, message: str):
    """
    Generates a response to the user's message.

    Parameters:
    message (str): The user's message.

    Yields:
    Event: A response event generated by the chatbot.

    Returns:
    List[Dict[str, str]]: A list of dictionaries representing the retrieved documents.

    """

    # Generate search queries (if any)
    response = co.chat(message=message, search_queries_only=True)

    # If there are search queries, retrieve documents and respond
    if response.search_queries:
        print("Retrieving information...")

        documents = self.retrieve_docs(response)

        response = co.chat(
            message=message,
            documents=documents,
            conversation_id=self.conversation_id,
            stream=True,
        )
        for event in response:
            yield event

    # If there is no search query, directly respond
    else:
        response = co.chat(
            message=message,
            conversation_id=self.conversation_id,
            stream=True
        )
        for event in response:
            yield event

  def retrieve_docs(self, response) -> List[Dict[str, str]]:
    """
    Retrieves documents based on the search queries in the response.

    Parameters:
    response: The response object containing search queries.

    Returns:
    List[Dict[str, str]]: A list of dictionaries representing the retrieved documents.

    """
    # Get the query(s)
    queries = []
    for search_query in response.search_queries:
        queries.append(search_query["text"])

    # Retrieve documents for each query
    retrieved_docs = []
    for query in queries:
        retrieved_docs.extend(self.docs.retrieve(query))

    return retrieved_docs

# %%
search_engine = SearchEngine(documents)

# %%
response = search_engine.generate_response(json.dumps(profiles[0]))

# %%
for event in response:
  # Text
  if event.event_type == "text-generation":
      print(event.text, end="")

  # Citations
  if event.event_type == "citation-generation":
      if not flag:
          print("\\n\\nCITATIONS:")
          flag = True
      citation = event.citations[0]
      start_idx = citation["start"]
      end_idx = citation["end"]
      print(event.citations)
# Out:
# Certainly! Here is an overview of the LinkedIn profile for Karan Gupta, a senior software engineer with over a decade of experience in the industry:
#
# ## Intro
#
# Karan Gupta is a seasoned software engineer currently working at Amazon as a Senior Software Engineer. Raised in Toronto, Canada, he possesses over ten years of experience in the software engineering industry. With a strong educational background in computer science and a passion for solving complex problems, he has made significant contributions to various high-profile projects throughout his career.
#
# ## Experience
#
# ...
